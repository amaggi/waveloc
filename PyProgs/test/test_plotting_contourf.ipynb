# %%
import pylab as pltimport numpy as np

# %%
r=np.random.randn(10,10)r[2,8]=10x=np.arange(10)*0.1+5y=np.arange(10)*0.2+10

# %%
plt.contourf(x,y,r.T)
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x10a6a3dd0>

# %%
plt.contourf(x,y,np.flipud(r.T))
# Out:
# <matplotlib.contour.QuadContourSet instance at 0x10a6e4098>
