# %%
from obspy.core import readimport pylab as pltimport numpy as np

# %%
st=read('../out/TEST_PdF/stack/stack_max*')st.merge()tr=st[0]th=4*np.median(tr.data)

# %%
plt.plot(tr.data)plt.axhline(th,c='r')
